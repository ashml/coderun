# %%
track_duration_seconds = 2 * 60 + 45
p_favorite = 0.2
p_hiphop_given_favorite = 1 / 3
p_favorite_hiphop = p_favorite * p_hiphop_given_favorite
expected_tracks = 1 / p_favorite_hiphop
total_time_seconds = expected_tracks * track_duration_seconds
print(int(total_time_seconds))
# Out:
# 2475
