# %%
N = 50
expected_points_from_pairs = (N**2 - 1) / 2
expected_deductions = 5 * N - 6 + 2 / N
expected_total_score = expected_points_from_pairs - expected_deductions
print(f"{expected_total_score:.2f}")
# Out:
# 1005.46
