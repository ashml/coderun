# %%
import pandas as pd

file_path = 'data/527_dishonest_artists/data_fix.csv'
data = pd.read_csv(file_path)

# %%
print(*data['driver'].unique()[-9:])
# Out:
# 87453549 68102783 59986309 89859153 49141855 90985908 39939250 46629985 73457819
