# %%
import numpy as np


P1 = 1/6
P2 = 1/3
P3 = 1/2


num_states = 11
T = np.zeros((num_states, num_states))

# State 0
T[0, 0] = 5/6
T[0, 1] = 1/6

# State 1
T[1, 0] = 1/2
T[1, 1] = 1/6
T[1, 2] = 1/3

# State 2
T[2, 0] = 1/3
T[2, 1] = 1/6
T[2, 3] = 1/2

# State 3
T[3, 0] = 5/6
T[3, 4] = 1/6

# State 4
T[4, 0] = 1/2
T[4, 1] = 1/6
T[4, 5] = 1/3

# State 5
T[5, 0] = 1/3
T[5, 6] = 1/6
T[5, 3] = 1/2

# State 6
T[6, 0] = 1/2
T[6, 1] = 1/6
T[6, 7] = 1/3

# State 7
T[7, 0] = 1/3
T[7, 1] = 1/6
T[7, 8] = 1/2

# State 8
T[8, 0] = 5/6
T[8, 9] = 1/6

# State 9
T[9, 0] = 1/2
T[9, 1] = 1/6
T[9, 10] = 1/3

# State 10
T[10, 10] = 1


Q = T[:10, :10]
I = np.eye(10)
N = np.linalg.inv(I - Q)
t = N @ np.ones(10)
expected_rolls = t[0]
print(f"{expected_rolls:.10f}")
# Out:
# 420569.9999995073
