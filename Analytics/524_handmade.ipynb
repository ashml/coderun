# %%
import pandas as pd
import matplotlib.pyplot as plt


file_path = "data/524_handmade/path.csv"
data = pd.read_csv(file_path)


plt.figure(figsize=(8, 8))
plt.plot(data['x'], data['y'], marker='o', linestyle='-', color='blue')
plt.title("График по координатам")
plt.xlabel("X координаты")
plt.ylabel("Y координаты")
plt.grid(True)
plt.axis('equal')
plt.show()

# %%
pure_data = data.drop(index=[7, 20, 21, 22, 27, 45, 73])

# %%
plt.figure(figsize=(8, 8))
plt.plot(pure_data['x'], pure_data['y'], marker='o', linestyle='-', color='blue')
plt.title("График по координатам")
plt.xlabel("X координаты")
plt.ylabel("Y координаты")
plt.grid(True)
plt.axis('equal')
plt.show()

# %%
def calculate_distance(x1, y1, x2, y2):
    return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

total_distance = 0
for i in range(1, len(pure_data)):
    total_distance += calculate_distance(pure_data.iloc[i-1]['x'], pure_data.iloc[i-1]['y'], pure_data.iloc[i]['x'], pure_data.iloc[i]['y'])

paint_consumption = total_distance / 1000
print(round(paint_consumption, 5))
# Out:
# 3.18015
