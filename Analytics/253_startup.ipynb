# %%
import pandas as pd


data = {
    "Day": range(1, 21),
    "Retention": [0.69, 0.41, 0.3, 0.26, 0.23, 0.2, 0.18, 0.15, 0.12, 0.11, 
                  0.08, 0.07, 0.05, 0.04, 0.03, 0.03, 0.03, 0.01, 0.01, 0]
}

df = pd.DataFrame(data)
lifetime = round(df["Retention"].sum())
print(lifetime)
