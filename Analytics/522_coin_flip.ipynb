# %%
p_H = 0.9
attempts = 15
k = 25

p_exceed = p_H**k
p_not_exceed = 1 - p_exceed
p_all_not_exceed = p_not_exceed**attempts
probability = 1 - p_all_not_exceed
print(round(probability, 4))
# Out:
# 0.6729
